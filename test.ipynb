# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

print("Pandas et Seaborn sont opérationnels")
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}) #Test
print(df)
# Out:
# Pandas et Seaborn sont opérationnels
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
